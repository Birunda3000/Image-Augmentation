# %%
import sys
import threading
from threading import Thread, Lock
import time 
import random
import pipe_instance
import data_sample
import utils
import matplotlib.pyplot as plt

# %%
lista_de_imagens = data_sample.data
print('Numero imagens na base - {}'.format(len(lista_de_imagens)))

plt.figure(figsize=(10,10))
m = 42
if( len(lista_de_imagens) < 90 ):
    m = len(lista_de_imagens)
for i in range(m):
    plt.subplot(6,7,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(lista_de_imagens[i][0])#, cmap='gray')
    plt.xlabel("{}\n({})".format( lista_de_imagens[i][1], '-' ), color='white')    
plt.show()
# Out:
# Numero imagens na base - 30

# %%
utils.call_thread(img_per_thread = 30, data = data_sample.data, pipe_instance = pipe_instance.pipe, image_per_image = 2)
# Out:
# Thread ID - 0
# Numero imagens na base - 90

# %%
'''
lista_de_imagens = 

plt.figure(figsize=(10,10))
m = 100
if( len(lista_de_imagens) < 90 ):
    m = len(lista_de_imagens)
for i in range(m):
    plt.subplot(10,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(lista_de_imagens[i][0])#, cmap='gray')
    plt.xlabel("{}\n({})".format( lista_de_imagens[i][1], '-' ), color='white')    
plt.show()
'''
# Out:
# '\nlista_de_imagens = \n\nplt.figure(figsize=(10,10))\nm = 100\nif( len(lista_de_imagens) < 90 ):\n    m = len(lista_de_imagens)\nfor i in range(m):\n    plt.subplot(10,10,i+1)\n    plt.xticks([])\n    plt.yticks([])\n    plt.grid(False)\n    plt.imshow(lista_de_imagens[i][0])#, cmap=\'gray\')\n    plt.xlabel("{}\n({})".format( lista_de_imagens[i][1], \'-\' ), color=\'white\')    \nplt.show()\n'
