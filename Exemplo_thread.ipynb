# %%
import pipe_example
import data_reading
import utils

# %%
pipe_example.pipe2.print_pipe()
# Out:
# Operações:

# %%
utils.print_list_img(data_reading.data_mnist_11)
# Out:
# Numero imagens - 30

# %%
resultado = utils.call_thread(data = data_reading.data_mnist_11, pipe_instance = pipe_example.pipe2, img_per_thread=100,
                              image_per_image = 2, salvar_imagens_gerada=False, caminho='../teste')
utils.print_list_img(resultado)
# Out:
# Thread 0: Executada com sucesso
# Arquivo gravado como: ../teste.pickle
# Numero imagens - 90

# %%
utils.print_list_img(data_reading.data_cifar10_10)
# Out:
# Numero imagens - 30

# %%
resultado = utils.call_thread(data = data_reading.data_cifar10_10, pipe_instance = pipe_example.pipe2, img_per_thread=100, 
                              image_per_image=1, salvar_imagens_gerada=False, caminho='../teste2')
utils.print_list_img(resultado)
# Out:
# Thread 0: Executada com sucesso
# Arquivo gravado como: ../teste2.pickle
# Numero imagens - 60
