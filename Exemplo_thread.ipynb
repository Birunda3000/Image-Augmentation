# %%
import pipe_example
import data_reading
import utils

# %%
pipe_example.pipe2.print_pipe()
# Out:
# Operações:
# |    Operação    | prob | skew_type | magnitude |
# |      Skew      |  1   |   RANDOM  |    0.5    |
#
# | -------------- | prob |
# |     Invert     |  1   |
#
# | -------------- | prob | percentage_area | randomise |
# |  Zoom_Random   |  1   |       0.6       |    True   |
#
# | -------------- | prob | rectangle_area | repetitions |
# | Random_Erasing |  1   |      0.3       |      3      |
#
# | -------------- | prob | horizontal_max | vertical_max | randomise |   fill  |
# |     Shift      |  1   |      0.3       |     0.3      |    True   | nearest |
#
# | -------------- | prob | max_left_rotation | max_right_rotation | fill |
# |    Rotacao     |  1   |         40        |         40         | edge |

# %%
utils.print_list_img(data_reading.data_mnist_11, limite=40)
# Out:
# Numero imagens - 30

# %%
resultado = utils.call_thread(data = data_reading.data_mnist_11, pipe_instance = pipe_example.pipe2, img_per_thread=10, retornar_img_originais=True,
                              image_per_image = 2, salvar_imagens_gerada=False, caminho='../teste')
utils.print_list_img(resultado)
# Out:
# Thread 0: Executada com sucesso
# Thread 2: Executada com sucesso
# Thread 1: Executada com sucesso
# Numero imagens - 90

# %%
utils.print_list_img(data_reading.data_cifar10_10)
# Out:
# Numero imagens - 30

# %%
resultado = utils.call_thread(data = data_reading.data_cifar10_10, pipe_instance = pipe_example.pipe2, img_per_thread=15, 
                              image_per_image=1, salvar_imagens_gerada=False, caminho='../teste2')
utils.print_list_img(resultado)
# Out:
# Thread 1: Executada com sucesso
# Thread 0: Executada com sucesso
# Numero imagens - 60
