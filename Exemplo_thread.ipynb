# %%
import pipe_example
import data_reading
import utils

# %%
pipe_example.pipe2.print()
# Out:
# Operações:
# |    Operação    | prob | skew_type | magnitude |
# |      Skew      | 0.3  |   RANDOM  |    0.5    |
#
# | -------------- | prob |
# |     Invert     | 0.3  |
#
# | -------------- | prob | percentage_area | randomise |
# |  Zoom_Random   | 0.3  |       0.6       |    True   |
#
# | -------------- | prob | rectangle_area | repetitions |
# | Random_Erasing |  1   |      0.3       |      3      |
#
# | -------------- | prob | horizontal_max | vertical_max | randomise |   fill  |
# |     Shift      | 0.3  |      0.3       |     0.3      |    True   | nearest |
#
# | -------------- | prob | max_left_rotation | max_right_rotation | fill |
# |    Rotacao     | 0.3  |         40        |         40         | edge |

# %%
nomes_classes = ['zero','um','dois','tres','quatro','cinco','seis','sete','oito','nove']
utils.print_list_img(data_reading.data_mnist_11, classes = nomes_classes)
# Out:
# Numero imagens - 110

# %%
resultado = utils.call_thread(img_per_thread = 100, data = data_reading.data_mnist_11, pipe_instance = pipe_example.pipe2, image_per_image = 2)
utils.print_list_img(resultado, classes = nomes_classes)
# Out:
# Thread 1: Executada com sucesso
# Thread 0: Executada com sucesso
# Numero imagens - 330

# %%
nomes_classes = ['horse', 'airplane', 'truck', 'bird', 'dog', 'cat', 'ship', 'deer', 'frog', 'automobile']
utils.print_list_img(data_reading.data_cifar10_10, classes = nomes_classes)

# %%
resultado = utils.call_thread(img_per_thread = 100, data = data_reading.data_cifar10_10, pipe_instance = pipe_example.pipe2, image_per_image = 1)
utils.print_list_img(resultado, classes = nomes_classes)
